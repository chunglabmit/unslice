# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')


# %matplotlib nbagg 
# %matplotlib notebook
# %matplotlib inline



## Third party 
import numpy as np
import os, time, zarr, sys
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import matplotlib as mpl

import unslice.IO as io
from unslice.utils import *
from unslice.registration.featmatch import *
from unslice.registration.transform import *
from unslice.registration.rigid import *
from unslice.registration.gpu_transform import *
from unslice.registration.utils import *
from unslice.segmentation import *
from unslice.tracing.pyoof import OOF, apply_oof_v2
from unslice.tracing.skel import *
from unslice.flatten import *
from unslice.lightsheetcorrect import *

# %%
# Parameters that are constant throughout notebook
working_dir = '/mnt/share3/webster/mEhmAD_2-3/tracing'

def bdir(fname):
    return os.path.join(working_dir, fname)

# prefix to add to the beginning of each filename 
name_prefix2 = '2-ptau_pred'
name_prefix = '3-ptau_pred'

# %%
preds_bot_zarr_path = bdir(name_prefix2+'_ptauwarp_r2.zarr')
preds_top_zarr_path = bdir(name_prefix+'.zarr')



preds_bot = zarr.open(preds_bot_zarr_path)
preds_top = zarr.open(preds_top_zarr_path)

# %%
print(preds_bot.shape, preds_top.shape)
# Out:
# (1277, 1072, 1274) (1024, 1024, 1000)

# %%
# We need to crop these to the right size 

# 2
xrange = [557-517,1581-517]
yrange = [76-64,1100-64]
zrange = [0,1274]
num_workers = 24
source_zarr_path = bdir(name_prefix2+'_ptauwarp_r2.zarr')
sink_zarr_path = bdir(name_prefix2+'_ptauwarp_r2_cropped.zarr')



###############
crop_zarr(source_zarr_path, sink_zarr_path, xrange=xrange, yrange=yrange, zrange=zrange, 
          load_num_slices=None, num_workers=num_workers)

# tiff_path = sink_zarr_path[:-5]+'_tiffs'
# convert_zarr_to_tiff(sink_zarr_path, tiff_path, num_workers=24)
# Out:
# Processing chunk x:40-1064, y:12-1036, z:0-200
# 100%|██████████| 36/36 [00:03<00:00,  9.71it/s]
# 100%|██████████| 36/36 [00:01<00:00, 21.75it/s]
# Processing chunk x:40-1064, y:12-1036, z:200-400
# 100%|██████████| 36/36 [00:07<00:00,  4.61it/s]
# 100%|██████████| 36/36 [00:02<00:00, 14.18it/s]
# Processing chunk x:40-1064, y:12-1036, z:400-600
# 100%|██████████| 36/36 [00:08<00:00,  4.27it/s]
# 100%|██████████| 36/36 [00:03<00:00, 11.84it/s]
# Processing chunk x:40-1064, y:12-1036, z:600-800
# 100%|██████████| 36/36 [00:08<00:00,  4.34it/s]
# 100%|██████████| 36/36 [00:02<00:00, 12.93it/s]
# Processing chunk x:40-1064, y:12-1036, z:800-1000
# 100%|██████████| 36/36 [00:07<00:00,  5.02it/s]
# 100%|██████████| 36/36 [00:02<00:00, 12.08it/s]
# Processing chunk x:40-1064, y:12-1036, z:1000-1200
# 100%|██████████| 36/36 [00:08<00:00,  4.50it/s]
# 100%|██████████| 36/36 [00:02<00:00, 12.28it/s]
# Processing chunk x:40-1064, y:12-1036, z:1200-1274
# 100%|██████████| 36/36 [00:03<00:00, 10.18it/s]
# 100%|██████████| 36/36 [00:01<00:00, 31.73it/s]

# %%
top_zarr_path = bdir(name_prefix+'.zarr')
bot_zarr_path = bdir(name_prefix2+'_ptauwarp_r2_cropped.zarr')
sink_path = bdir('2-3_ptau_pred_combined.zarr')
overlap_range = [311,1000] # which slices of top_zarr are overlapping 
mode='max'
num_workers = None

utils.image_calculator(top_zarr_path, bot_zarr_path, sink_path, 
                    image1_slice_range=overlap_range, mode=mode, num_workers=num_workers)

# check
tiff_path = sink_path[:-5]+'_tiffs'
convert_zarr_to_tiff(sink_path, tiff_path, num_workers=24)
# Out:
# Time elapsed for memory-intensive assignment: 76.16029167175293
# Loading z 0 - 200
# 100%|██████████| 36/36 [00:03<00:00, 11.26it/s]
# 100%|██████████| 200/200 [00:10<00:00, 18.43it/s]
# Loading z 200 - 400
# 100%|██████████| 36/36 [00:02<00:00, 12.99it/s]
# 100%|██████████| 200/200 [00:05<00:00, 38.08it/s]
# Loading z 400 - 600
# 100%|██████████| 36/36 [00:02<00:00, 12.71it/s]
# 100%|██████████| 200/200 [00:09<00:00, 21.25it/s]
# Loading z 600 - 800
# 100%|██████████| 36/36 [00:02<00:00, 13.26it/s]
# 100%|██████████| 200/200 [00:10<00:00, 18.85it/s]
# Loading z 800 - 1000
# 100%|██████████| 36/36 [00:02<00:00, 13.19it/s]
# 100%|██████████| 200/200 [00:07<00:00, 26.73it/s]
# Loading z 1000 - 1200
# 100%|██████████| 36/36 [00:05<00:00,  6.25it/s]
# 100%|██████████| 200/200 [00:06<00:00, 31.59it/s]
# Loading z 1200 - 1400
# 100%|██████████| 36/36 [00:06<00:00,  5.90it/s]
# 100%|██████████| 200/200 [00:05<00:00, 35.00it/s]
# Loading z 1400 - 1585
# 100%|██████████| 36/36 [00:03<00:00,  9.09it/s]
# 100%|██████████| 185/185 [00:06<00:00, 26.93it/s]

# %% [markdown]
# # Run segmentation, skeletonization on this

# %%
# Now set the parameters 
# Need one set for the top surface and one set for the bottom surface of each slab 

zarr_path = bdir('2-3_ptau_pred_combined.zarr')
zarr_segmented_path = bdir('2-3_ptau_pred_combined_segmented.zarr') # bdir('vessel_tests/'+name_prefix+'_segmented.zarr')

sample_coord_ranges = None #[[[0,1000],[0,1000],[0,400]]]
threshold_type = "set" # "set" or "graphcut" or "otsu"

if threshold_type == 'set':
    intensity_thresholds = [62000]
    morphopts = [None]

    for i in range(len(intensity_thresholds)):
        opts = {
            'percentile_threshold': intensity_thresholds[i],
            'threshold_type': threshold_type,
            'morphopts': morphopts[i],
            'num_workers': 24,
            'sample_coord_ranges': sample_coord_ranges
        }
        
        threshold_image(zarr_path, zarr_segmented_path, **opts)
        
elif threshold_type == 'graphcut':
    min_thresholds = [.25*65535]
    saturate_image_thresholds = [.95*65535]
    morphopts = [None]  #[('dilate','ball',2)]*2
    
    for i in range(len(min_thresholds)):
        opts = {
            'min_threshold' : min_thresholds[i], # This sets a minimum intensity threshold for pixels 
            'saturate_image_threshold' : saturate_image_thresholds[i],
            'k' : 2,
            'alpha' : 0.25,
            'num_workers' : 24,
            'overlap' : 25,
            'morphopts' : morphopts[i],
            'sample_coord_ranges' : sample_coord_ranges 
            }
        zarr_graphcut3d(zarr_path, zarr_segmented_path, **opts)
# Out:
# 100%|██████████| 288/288 [00:22<00:00, 12.62it/s]

# %% [markdown]
# ## Connected components

# %% [markdown]
# ### Region 1

# %%
# view segmentation
zarr_segmented_path = bdir('2-3_ptau_pred_combined_segmented.zarr')
z = zarr.open(zarr_segmented_path)
img = z[:]

# io.writeData(zarr_segmented_path[:-5]+'.tif',img)

# %%
from skimage import measure
from skimage import filters

img1 = img[300:600,0:236,70:732].astype('uint8')

img1_graph = measure.label(img1)

# %%
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732.tif'), img1_graph.astype('uint16'))
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732.tif'

# %%
print(img1.shape, img.shape)
# Out:
# (300, 236, 662) (1024, 1024, 1585)

# %%
img1_graph_ccs = img1_graph[img1_graph>0].ravel()

# %%
plt.figure()
plt.hist(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
counts,bins= np.histogram(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))

# %%
print(counts.max(), counts.min(), counts.mean(), counts.std())
print(np.argmax(counts)+1)
# Out:
# 114919 1 1713.0444033302497 5194.311442489814
# 417

# %%
idx = 419

#print(len(np.argwhere(img1_graph_ccs==idx)))
counts[idx-1]
# Out:
# 26996

# %%
# First, we save a version with just the relevant fiber highlighted

idx = 417 


######
img1_ = (img1_graph == idx).astype('uint8')
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732_longfiber.tif'), img1_)
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732_longfiber.tif'

# %%
print(np.sort(counts)[-2])
print(np.argwhere(counts==np.sort(counts)[-2])+1)
# Out:
# 52028
# [[643]]

# %%
# Make new images for the two other fibers
# First, we save a version with just the relevant fiber highlighted

idx = 239 
idx2 = 419


######
img1_ = (img1_graph == idx).astype('uint8') + (img1_graph == idx2).astype('uint8')
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732_longfiber2.tif'), img1_)
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x300-600_y0-236_z70-732_longfiber2.tif'

# %% [markdown]
# ### Region 2

# %%
# view segmentation
zarr_segmented_path = bdir('2-3_ptau_pred_combined_segmented.zarr')
z = zarr.open(zarr_segmented_path)
img = z[:]

# io.writeData(zarr_segmented_path[:-5]+'.tif',img)

# %%
from skimage import measure
from skimage import filters

img1 = img[450:800,310:600,189:772].astype('uint8')


print(img1.shape, img.shape)
img1_graph = measure.label(img1)
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772.tif'), img1_graph.astype('uint16'))
# Out:
# (350, 290, 583) (1024, 1024, 1585)
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772.tif'

# %%
img1_graph_ccs = img1_graph[img1_graph>0].ravel()
plt.figure()
plt.hist(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
counts,bins= np.histogram(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))

# %%
print(counts.max(), counts.min(), counts.mean(), counts.std())
print(np.argmax(counts)+1)
# Out:
# 107208 1 1959.989326765189 6591.499748666285
# 503

# %%
idx = 391

# 503,575,

#print(len(np.argwhere(img1_graph_ccs==idx)))
counts[idx-1]
# Out:
# 21595

# %%
# Make new images for the two other fibers
# First, we save a version with just the relevant fiber highlighted

idx = 503 
idx2 = 575


######
img1_ = (img1_graph == idx).astype('uint8') + (img1_graph == idx2).astype('uint8')
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772_longfiber.tif'), img1_)
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772_longfiber.tif'

# %%
print(np.sort(counts)[-2])
print(np.argwhere(counts==np.sort(counts)[-2])+1)
# Out:
# 98824
# [[328]]

# %%
# Second fiber

idx = 391 


######
img1_ = (img1_graph == idx).astype('uint8')
io.writeData(bdir('2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772_longfiber2.tif'), img1_)
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_conncomp_x450-800_y310-600_z189-772_longfiber2.tif'

# %% [markdown]
# # Make skeleton for Fig8 visualization

# %%
zarr.open(bdir('2-3_ptau_pred_combined.zarr')).shape
# Out:
# (1024, 1024, 1585)

# %%
# Now set the parameters 
# Need one set for the top surface and one set for the bottom surface of each slab 

zarr_path = bdir('2-3_ptau_pred_combined.zarr')
zarr_segmented_path = bdir('2-3_ptau_pred_combined_segmented_graphcut.zarr') # bdir('vessel_tests/'+name_prefix+'_segmented.zarr')

sample_coord_ranges = None #[[[400,600],[400,600],[600,800]]]
threshold_type = "graphcut" # "set" or "graphcut" or "otsu"

if threshold_type == 'set':
    intensity_thresholds = [62500]
    morphopts = [None]

    for i in range(len(intensity_thresholds)):
        opts = {
            'percentile_threshold': intensity_thresholds[i],
            'threshold_type': threshold_type,
            'morphopts': morphopts[i],
            'num_workers': 24,
            'sample_coord_ranges': sample_coord_ranges
        }
        
        threshold_image(zarr_path, zarr_segmented_path, **opts)
        
elif threshold_type == 'graphcut':
    min_thresholds = [.5*65535]
    saturate_image_thresholds = [65535]
    morphopts = [None]  #[('dilate','ball',2)]*2
    
    for i in range(len(min_thresholds)):
        opts = {
            'min_threshold' : min_thresholds[i], # This sets a minimum intensity threshold for pixels 
            'saturate_image_threshold' : saturate_image_thresholds[i],
            'k' : 2,
            'alpha' : 5,
            'num_workers' : 24,
            'overlap' : 25,
            'morphopts' : morphopts[i],
            'sample_coord_ranges' : sample_coord_ranges 
            }
        zarr_graphcut3d(zarr_path, zarr_segmented_path, **opts)
# Out:
# Starting image preprocessing..
# Saturated image processed in 0.393831 minutes
# 100%|██████████| 288/288 [09:37<00:00,  2.00s/it]

# %%
zarr.open(bdir('2-3_ptau_pred_combined.zarr')).shape
# Out:
# (1024, 1024, 1585)

# %%
# Now set the parameters 
# Need one set for the top surface and one set for the bottom surface of each slab 

zarr_path = bdir('2-3_ptau_pred_combined.zarr')
zarr_segmented_path = bdir('2-3_ptau_pred_combined_segmented_graphcut.zarr') # bdir('vessel_tests/'+name_prefix+'_segmented.zarr')

sample_coord_ranges = None #[[[400,600],[400,600],[1000,1200]]]
threshold_type = "graphcut" # "set" or "graphcut" or "otsu"

if threshold_type == 'set':
    intensity_thresholds = [62500]
    morphopts = [None]

    for i in range(len(intensity_thresholds)):
        opts = {
            'percentile_threshold': intensity_thresholds[i],
            'threshold_type': threshold_type,
            'morphopts': morphopts[i],
            'num_workers': 24,
            'sample_coord_ranges': sample_coord_ranges
        }
        
        threshold_image(zarr_path, zarr_segmented_path, **opts)
        
elif threshold_type == 'graphcut':
    min_thresholds = [.75*65535]
    saturate_image_thresholds = [65535]
    morphopts = [None]  #[('dilate','ball',2)]*2
    
    for i in range(len(min_thresholds)):
        opts = {
            'min_threshold' : min_thresholds[i], # This sets a minimum intensity threshold for pixels 
            'saturate_image_threshold' : saturate_image_thresholds[i],
            'k' : 2,
            'alpha' : 5,
            'num_workers' : 24,
            'overlap' : 25,
            'morphopts' : morphopts[i],
            'sample_coord_ranges' : sample_coord_ranges 
            }
        zarr_graphcut3d(zarr_path, zarr_segmented_path, **opts)
# Out:
# Starting image preprocessing..
# Saturated image processed in 0.480327 minutes
# 100%|██████████| 288/288 [09:38<00:00,  2.01s/it]

# %% [markdown]
# # Skeletonization

# %%
surf_zarr_path = None 
segmented_path = bdir('2-3_ptau_pred_combined_segmented_graphcut.zarr')
skel_path = bdir('1-3_ptau_pred_combined_segmented_graphcut_skel.zarr')
min_branch_length = 25
min_cc = 60
overlap = 25 # make sure this is much greater than the min_cc and min_branch_length 
num_workers = 24

# Kwargs for prune_directionality 
prune_directionality_num_points = 4
orientation = 'top' # first we get all the top surface points 


############# Perform skeletonization ##############
start = time.time()
top_endpoints = trace_zarr(segmented_path, surf_zarr_path, skel_path,
                      min_branch_length, min_cc, overlap=overlap, num_workers=num_workers,
                      prune_directionality_num_points=prune_directionality_num_points,
                      orientation=orientation)
print("Time elapsed: %f hours" %((time.time()-start)/3600))
# Out:
# 100%|██████████| 288/288 [00:27<00:00, 10.56it/s]
# Time elapsed: 0.008076 hours

# %%
# view skeleton
z = zarr.open(skel_path)
img = z[:]

io.writeData(skel_path[:-5]+'.tif',img)
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/1-3_ptau_pred_combined_segmented_graphcut_skel.tif'

# %%
img.shape
# Out:
# (1024, 1024, 1585)

# %%
from skimage import measure
from skimage import filters

img1 = img.astype('uint8')


print(img1.shape, img.shape)
img1_graph = measure.label(img1)
#io.writeData(bdir('1-3_ptau_pred_combined_segmented_conncomp_x0-917_y52-385_z366-792.tif'), img1_graph.astype('uint16'))
# Out:
# (1024, 1024, 1585) (1024, 1024, 1585)

# %%
img1_graph_ccs = img1_graph[img1_graph>0].ravel()
plt.figure()
plt.hist(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))
plt.ylim([0,10000])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
counts,bins= np.histogram(img1_graph_ccs, bins=len(np.unique(img1_graph_ccs)))

print(counts.max(), counts.min(), counts.mean(), counts.std())
print(np.argmax(counts)+1)
# Out:
# 10601 1 205.88911128903123 497.4642755795768
# 1057

# %%
threshold_cc = 250

idxs = np.argwhere(counts > threshold_cc)+1
print(len(idxs))
# Out:
# 425

# %%
start = time.time()
temp2 = np.isin(img1_graph,idxs.ravel())
print(time.time()-start)
# Out:
# 113.02807927131653

# %%
# We need to add some radius to this so that we can actually see it on Imaris 

start = time.time()
temp2_ = apply_morphological_op(temp2, 'dilate', 'ball', 3)
print(time.time()-start)
# Out:
# 166.2960033416748

# %%
io.writeData(bdir('2-3_ptau_pred_combined_segmented_graphcut_skel_filtered.tif'), temp2_.astype('uint8'))
# Out:
# '/mnt/share3/webster/mEhmAD_2-3/tracing/2-3_ptau_pred_combined_segmented_graphcut_skel_filtered.tif'
